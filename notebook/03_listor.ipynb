# %% [markdown]
# Listor är en lista över värden som man samlar ihop
#
# Här är tillexempel en lista över betyg man kan få

# %%
betyg = ["A", "B", "C", "D", "E", "F"]
print(f"Här är listan: {betyg}")
print(f"Här är första värdet i listan {betyg[0]}")
print(f"Här är andra värdet i listan {betyg[1]}")
print(f"Här är sista värdet i listan {betyg[-1]}")
# Out:
# Här är listan: ['A', 'B', 'C', 'D', 'E', 'F']
# Här är första värdet i listan A
# Här är andra värdet i listan B
# Här är sista värdet i listan F

# %% [markdown]
# Vad kan man göra med detta då?
#
# Jo att samla ihop värden kan ofta vara bra, tillexempel kan vi ta fram ett slumpmässigt (random) betyg

# %%
import random
print(f"Ditt betyg i kursen blir: {random.choice(betyg)}")
# Out:
# Ditt betyg i kursen blir: C

# %% [markdown]
# ### Här kommer jag försöka förklara vad det är som händer:
#
#     import random
#
# Här laddar vi in random-biblioteket. Det är alltså kod som någon
# annan har skrivit som vi kan använda
#
#     print(f"Ditt betyg i kursen blir: {random.choice(betyg)}")
#     ^
#
# Vi börjar med att printa
#
#     print(f"Ditt betyg i kursen blir: {random.choice(betyg)}")
#                                        ^
# Nu kallar vi på random-biblioteket
#
#     print(f"Ditt betyg i kursen blir: {random.choice(betyg)}")
#                                               ^
# Från random-biblioteket kallar vi här på choice funktionen. choice funktionen vill ha en lista och där skriver vi in vår lista som heter betyg. När choice funktionen är färdig så returnerar den ett av betygen, och det är det som vi sedan printar.
#
# ### Om vi ska lägga till något i listan använder vi något som heter append

# %%
betyg.append("A+")
print(f"Här är listan: {betyg}")
# Out:
# Här är listan: ['A', 'B', 'C', 'D', 'E', 'F', 'A+']

# %% [markdown]
# Som ni ser hamnar det nya värdet längst bak
# Att ta bort något gör vi med remove

# %%
betyg.remove("F")
print(f"Här är listan: {betyg}")
# Out:
# Här är listan: ['A', 'B', 'C', 'D', 'E', 'A+']

# %% [markdown]
# Man kan också använda pop för att ta bort något på en specifik plats

# %%
print(f"Denna kommer försvinna {betyg[2]}")
betyg.pop(2)
print(f"Här är listan: {betyg}")
# Out:
# Denna kommer försvinna C
# Här är listan: ['A', 'B', 'D', 'E', 'A+']

# %% [markdown]
# ## Indexering
#
# För att välja ett visst objekt i en lista kan man använda indexering. Om jag tillexempel vill printa ut det första i en list använder man index[0]. Titta på följande exempel:

# %%
betyg[0]
# Out:
# 'A'

# %% [markdown]
# För att visa det sista värdet kan man använda index[-1]

# %%
betyg[-1]
# Out:
# 'A+'

# %% [markdown]
# För att kolla hur många värden som finns i en lista kan man använda (len)

# %%
len(betyg)
# Out:
# 5

# %% [markdown]
# ## for-loop
#
# Om vi ska göra någonting med listan kan man använda en for-loop. **När ni tänker på for-loop tänk då så här**
#
#     För varje sak i en lista, gör såhär
#
# Titta på följande exempel där vi

# %% [markdown]
# # Övningar
#
# Här kommer lite övningar som har med listor att göra
#
# ## Övning 1
# Skapa en ny lista som har 1-5 istället för F-A betyg.

# %%
betygSiffror = []

# %% [markdown]
# ## Övning 2
#
# Skriv ut den första och sista siffran från din lista

# %% [markdown]
# ## Övning 3
#
# Gör en lista med dina 5 favoriträtter och printa ut 2 stycken slumpmässiga rätter
