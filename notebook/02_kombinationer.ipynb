# %% [markdown]
# # Kombinationer av variabler
#
# Med variabler så finns det speciella regler för vilka typer av variabler som kan kombineras med varandra. I kod exemplet nedan finns lite exempel på hur variabler kan kombineras.

# %% [markdown]
# Vi börjar med en vanlig textVariabel

# %%
textVariabel = "text"
print(f"{textVariabel}")
# Out:
# text

# %%
# textVariabel += 42
# Så här kan man INTE göra, man kan inte lägga till en int på en string

# Vi testar skapa en intvariabel som vi kan lägga till

# %%
intVariabel = 42

# %% [markdown]
# > textVariabel += intVariabel
#
# Såhär får man INTE heller göra

# %%
textVariabel += "42"
print(f"Såhär kan man dock göra: {textVariabel}")
# Out:
# Såhär kan man dock göra: text42

# %%
textVariabel += str(intVariabel)
print(f"Såhär kan man också genom att gör om int till string: {textVariabel}")
# Out:
# Såhär kan man också genom att gör om int till string: text4242

# %%
# Vi gör en floatvariabel också
floatVariabel = 3.14

# %%
# Vi kan addera en float på en int, för båda är ett "tal"
intVariabel += floatVariabel
print(f"Intvariabel efter addering {intVariabel}")
# Men tänk på att int variabeln nu är en float
print(f"Typen på intVariabel: {type(intVariabel)}")
# Out:
# Intvariabel efter addering 45.14
# Typen på intVariabel: <class 'float'>

# %% [markdown]
# # Övningar:
#
# Här under kommer lite övningar där ni ska öva på hur man kan kombinera olika instruktioner och variabeltyper

# %% [markdown]
# ## Övning 1
#
# Räkna ut summan av num1 och num2

# %%
num1 = 42
num2 = "69"
summa = num1 + num2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 num1 = 42
#       2 num2 = "69"
# ----> 3 summa = num1 + num2
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ## Övning 2
# Gör så att summan visas utan decimaler

# %%
num1 = 42
num2 = 3.14
summa = num1 + num2
print(summa)
# Out:
# 45.14

# %% [markdown]
# ## Övning 3
